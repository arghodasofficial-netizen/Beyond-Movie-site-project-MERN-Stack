# %% [markdown]
# <a href="https://colab.research.google.com/github/arghodasofficial-netizen/Beyond-Movie-site-project-MERN-Stack/blob/main/Introduction_to_Data_Science_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The Python Programming Language: Functions

# %%
def add_numbers(x,y):
  return x+y
add_numbers(1,3)
# Out:
# 4

# %%
def add_new_numbers(x,y,z):
  return x+y+z
add_new_numbers(1,2,3)
# Out:
# 6
